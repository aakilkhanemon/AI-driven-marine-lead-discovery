# %% [markdown]
# <a href="https://colab.research.google.com/github/aakilkhanemon/AI-driven-marine-lead-discovery/blob/main/RNNs_Scoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 40.8 MB/s eta 0:00:00
# ...

# %%
pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.1/37.1 MB 53.5 MB/s eta 0:00:00
# ...

# %%
# Activate the DiffDock environment
conda activate diffdock

# Verify your GPU is accessible by PyTorch
python -c "import torch; print('GPU Available:', torch.cuda.is_available())"
# Out:
#   File "/tmp/ipykernel_1834/3000016035.py", line 2
#     conda activate diffdock
#           ^
# SyntaxError: invalid syntax

# %%
# Verify GPU availability directly via python shell command
# !python -c "import torch; print('GPU Available:', torch.cuda.is_available())"
# Out:
# GPU Available: True

# %%
python -m inference \
    --protein_path cleaned_receptor.pdb \
    --ligand cleaned_ligand.sdf \
    --out_dir ./docking_outputs \
    --samples_per_complex 20 \
    --model_dir workdir/paper_models \
    --confidence_model_dir workdir/paper_confidence_model \
    --inference_steps 20 \
    --batch_size 10
# Out:
#   File "/tmp/ipykernel_1834/3097884483.py", line 1
#     python -m inference \
#               ^
# SyntaxError: invalid syntax

# %%
# !python -m inference \
    --protein_path receptor.pdb \
    --ligand ligand.sdf \
    --out_dir ./docking_outputs \
    --samples_per_complex 20 \
    --model_dir workdir/paper_models \
    --confidence_model_dir workdir/paper_confidence_model \
    --inference_steps 20 \
    --batch_size 10
# Out:
# /usr/bin/python3: No module named inference

# %%
# 1. Clone the DiffDock repository if it isn't in your sidebar
# !git clone https://github.com/gcorso/DiffDock.git
# %cd DiffDock

# 2. Re-verify your file locations
# Since your files are in the parent directory, we point to ../receptor.pdb and ../ligand.sdf
# !python -m inference \
    --protein_path ../receptor.pdb \
    --ligand ../ligand.sdf \
    --out_dir ./docking_outputs \
    --samples_per_complex 20 \
    --model_dir workdir/paper_models \
    --confidence_model_dir workdir/paper_confidence_model \
    --inference_steps 20 \
    --batch_size 10
# Out:
# Cloning into 'DiffDock'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 520 (delta 209), reused 154 (delta 154), pack-reused 227 (from 3)
# Receiving objects: 100% (520/520), 233.08 MiB | 35.20 MiB/s, done.
# Resolving deltas: 100% (244/244), done.
# /content/DiffDock
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/DiffDock/inference.py", line 21, in <module>
#     from torch_geometric.loader import DataLoader
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
# Install PyTorch Geometric dependencies
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-2.0.0+cu118.html

# Install additional cheminformatics dependencies DiffDock requires
# !pip install biopython rdkit pandas e3nn
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.0.0+cu118.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.2 MB/s eta 0:00:00
# ...

# %%
# !python -m inference \
    --protein_path ../receptor.pdb \
    --ligand ../ligand.sdf \
    --out_dir ./docking_outputs \
    --samples_per_complex 20 \
    --model_dir workdir/paper_models \
    --confidence_model_dir workdir/paper_confidence_model \
    --inference_steps 20 \
    --batch_size 10
