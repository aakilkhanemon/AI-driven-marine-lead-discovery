# %% [markdown]
# <a href="https://colab.research.google.com/github/aakilkhanemon/AI-driven-marine-lead-discovery/blob/main/gnina_90s_3l4q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install chemoinformatics analytics suites quietly
# !pip install -q rdkit mdanalysis pandas

# 2. Fetch and initialize the verified C++ GNINA binary
# !wget -q https://github.com/gnina/gnina/releases/download/v1.1/gnina -O gnina
# !chmod +x gnina

print("=== SCREENING ENVIRONMENT READY ===")
# Out:
# === SCREENING ENVIRONMENT READY ===

# %%
# !./gnina -r receptor.pdb -l ligands_90.sdf \
        --center_x -24.980 --center_y -2.037 --center_z -27.028 \
        --size_x 20 --size_y 20 --size_z 20 \
        --num_modes 3 --device 0 --cnn_scoring rescore \
        --out screened_results.sdf \
        --log screening_run.log
# Out:
# Streaming output truncated to the last 5000 lines.
# *** Open Babel Warning  in parseAtomRecord
#   WARNING: Problems reading a PDB file
#   Problems reading a HETATM or ATOM record.
#   According to the PDB specification,
#   columns 77-78 should contain the element symbol of an atom.
#   but OpenBabel found '  ' (atom 600)
# ...
# *** Open Babel Warning  in parseAtomRecord
#   WARNING: Problems reading a PDB file
#   Problems reading a HETATM or ATOM record.
#   According to the PDB specification,
#   columns 77-78 should contain the element symbol of an atom.
#   but OpenBabel found '  ' (atom 601)
# ...
# *** Open Babel Warning  in parseAtomRecord
#   WARNING: Problems reading a PDB file
#   Problems reading a HETATM or ATOM record.
#   According to the PDB specification,
#   columns 77-78 should contain the element symbol of an atom.
#   but OpenBabel found '  ' (atom 602)
# ...
# *** Open Babel Warning  in parseAtomRecord
#   WARNING: Problems reading a PDB file
# ...
